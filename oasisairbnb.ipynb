# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data1=pd.read_csv('C:/Users/HP/Downloads/AB_NYC_2019.csv', header = 0)

# %% [markdown]
# # AIRBNB DATA CLEANING

# %% [markdown]
# ## General Cleaning Steps;
# * Drop Duplicates
# * Data type Conversion
# * Replacing Missing Values
# * Standardization
# * Outlier Detection

# %%
data1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data1.shape
# Out:
# (48895, 16)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ## MY DATA CLEANING PROCESS

# %% [markdown]
# # Count Duplicates

# %%
data1.duplicated().value_counts()
# Out:
# False    48895
# Name: count, dtype: int64

# %% [markdown]
# # Percentage of missing values

# %%
round(data1.isnull().sum()/len(data1)*100,2).sort_values(ascending = False)
# Out:
# last_review                       20.56
# reviews_per_month                 20.56
# host_name                          0.04
# name                               0.03
# id                                 0.00
# host_id                            0.00
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %% [markdown]
# # Data type mismatch and conversion

# %% [markdown]
# ### converting id and host_id to object datatype

# %%
data1[['id','host_id']]= data1[['id','host_id']].astype('str')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  object
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  object
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data1.sample(3)
# Out:
#              id                                               name   host_id  \
# 4459    3058087  Fully Furnished Luk Room including Air Conditi...   5986790
# 8475    6515562                         STUDIO in the East Village  14979188
# 18410  14472385  Large Private 1BR Apartment- Best Location Che...  16756301
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 4459        Gen           Manhattan  Washington Heights  40.83568  -73.94457
# 8475     Esther           Manhattan        East Village  40.72781  -73.98620
# 18410    Alexis           Manhattan             Chelsea  40.74370  -73.99896
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 4459      Private room     40              31                  2   6/16/2019
# 8475   Entire home/apt    110               4                  3   8/27/2015
# 18410  Entire home/apt    249               7                 70    7/2/2019
#
# ...

# %% [markdown]
# ### converting last reviews to datetime data type

# %%
data1['last_review']=pd.to_datetime(data1['last_review'])
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  object
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  object
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ### Replacing missing values with zero

# %%
data1['reviews_per_month'] = data1['reviews_per_month'].fillna(0)

# %% [markdown]
# ### To view a sample dataframe of the replaced missing values

# %%
data1[data1['last_review'].isnull()].sample(6)
# Out:
#              id                                    name    host_id host_name  \
# 37450  29710463    2 bedroom, one bath in Crown Heights  203302656    Nadine
# 25308  20235591      Spacious Studio with computer desk  144200262      Anna
# 35710  28344161             One Bedroom in Midtown East   15736460   Shirley
# 27194  21490894                       BRIGHT SUNNY LOFT   56411266     Colin
# 3682    2216470                       Comfortable Room    11306420    Darius
# 34851  27629043  A Night at Anchor Aboard Yacht Ventura   45863742     James
#
#       neighbourhood_group              neighbourhood  latitude  longitude  \
# 37450            Brooklyn  Prospect-Lefferts Gardens  40.66249  -73.95075
# 25308               Bronx            North Riverdale  40.90734  -73.90137
# 35710           Manhattan                    Midtown  40.76054  -73.96425
# 27194            Brooklyn         Bedford-Stuyvesant  40.68994  -73.95908
# ...

# %% [markdown]
# ### Calculate the percentage of missing values

# %%
round(data1.isnull().sum()/len(data1)*100,2).sort_values(ascending = False)
# Out:
# last_review                       20.56
# host_name                          0.04
# name                               0.03
# id                                 0.00
# host_id                            0.00
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# reviews_per_month                  0.00
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %%
data1[data1['host_name'].isnull()].sample(6)
# Out:
#              id                                               name    host_id  \
# 6582    4763327                Luxurious, best location, spa inc'l   24576978
# 14040  10709846                 Sunny, spacious room in Greenpoint    7822683
# 27962  21867710  Amazing room in the centre on Manhatten! Welcome!  159156636
# 8257    6360224                    Sunny, Private room in Bushwick   33134899
# 28042  21901156  Best Deal! Lovely place in Manhattan! Time Squ...  159156636
# 360      100184                                          Bienvenue     526653
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 6582        NaN            Brooklyn      Greenpoint  40.72035  -73.95355
# 14040       NaN            Brooklyn      Greenpoint  40.73539  -73.95838
# 27962       NaN           Manhattan  Hell's Kitchen  40.75668  -73.99097
# 8257        NaN            Brooklyn        Bushwick  40.70146  -73.92792
# ...

# %%
data1[data1['name'].isnull()].sample(6)
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 6269    4581788  NaN  21600904     Lucie            Brooklyn
# 8841    6782407  NaN  31147528  Huei-Yin            Brooklyn
# 2854    1615764  NaN   6676776     Peter           Manhattan
# 18047  14135050  NaN  85288337      Jeff            Brooklyn
# 5975    4370230  NaN  22686810   Michaël           Manhattan
# 6567    4756856  NaN   1832442  Carolina            Brooklyn
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 6269         Williamsburg  40.71370  -73.94378     Private room    150
# 8841         Williamsburg  40.71354  -73.93882     Private room     45
# 2854    Battery Park City  40.71239  -74.01620  Entire home/apt    400
# 18047  Bedford-Stuyvesant  40.69421  -73.93234     Private room     70
# 5975               Nolita  40.72046  -73.99550  Entire home/apt    215
# 6567             Bushwick  40.70046  -73.92825     Private room     70
#
# ...

# %%
round(data1.isnull().sum()/len(data1)*100,2).sort_values(ascending = False)
# Out:
# last_review                       20.56
# host_name                          0.04
# name                               0.03
# id                                 0.00
# host_id                            0.00
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# reviews_per_month                  0.00
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  object
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  object
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data1.head(20)
# Out:
#       id                                              name host_id  \
# 0   2539                Clean & quiet apt home by the park    2787
# 1   2595                             Skylit Midtown Castle    2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !    4632
# 3   3831                   Cozy Entire Floor of Brownstone    4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park    7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East    7322
# 6   5121                                   BlissArtsSpace!    7356
# 7   5178                  Large Furnished Room Near B'way     8967
# 8   5203                Cozy Clean Guest Room - Family Apt    7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm    7549
# 10  5295                  Beautiful 1br on Upper West Side    7702
# 11  5441                   Central Manhattan/near Broadway    7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental    9744
# ...

# %% [markdown]
# ## Outliers Treatment

# %%
data1.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
# std        0.054530      0.046157    240.154170       20.510550
#
#        number_of_reviews                    last_review  reviews_per_month  \
# count       48895.000000                          38843       48895.000000
# mean           23.274466  2018-10-04 01:47:23.910099456           1.090910
# min             0.000000            2011-03-28 00:00:00           0.000000
# 25%             1.000000            2018-07-08 00:00:00           0.040000
# ...

# %%
data1.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
# std        0.054530      0.046157    240.154170       20.510550
#
#        number_of_reviews                    last_review  reviews_per_month  \
# count       48895.000000                          38843       48895.000000
# mean           23.274466  2018-10-04 01:47:23.910099456           1.090910
# min             0.000000            2011-03-28 00:00:00           0.000000
# 25%             1.000000            2018-07-08 00:00:00           0.040000
# ...

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(data1['number_of_reviews'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9140\2927493366.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['number_of_reviews'])
# <Axes: xlabel='number_of_reviews', ylabel='Density'>

# %%
# to see outliers clearly
sns.boxplot(data1['number_of_reviews'])
# Out:
# <Axes: ylabel='number_of_reviews'>

# %%
# define a function called "plot_boxplot"

def plot_boxplot(df, ft):
    df.boxplot(column=[ft])
    plt.grid(false)
    plt.show()

# %%
plot_boxplot(data1, "price")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plot_boxplot(data1, "price")
#
# Cell In[26], line 5, in plot_boxplot(df, ft)
#       3 def plot_boxplot(df, ft):
#       4     df.boxplot(column=[ft])
# ----> 5     plt.grid(false)
#       6     plt.show()
#
# NameError: name 'false' is not defined

# %% [markdown]
# ## IQR method

# %%
q1 = data1['price'].quantile(0.25)
q3 =data1['price'].quantile(0.75)
iqr = q3 -q1

# %%
q1,q3,iqr
# Out:
# (69.0, 175.0, 106.0)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 -(1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-90.0, 334.0)

# %%
sns.boxplot(data1['price'])
# Out:
# <Axes: ylabel='price'>

# %%
# finf the outliers
data1.loc[(data1['price']> upper_limit) | (data1['price']< lower_limit)]
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 121       27659                   3 Story Town House in Park Slope     119588
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %%
# trim - deleting the outliers data
new_data = data1.loc[(data1['price'] <upper_limit) & (data1['price']> lower_limit)]
print('before removing outliers:', len(data1))
print('after removing outliers:', len (new_data))
print('outliers:', len(data1)-len(new_data))
# Out:
# before removing outliers: 48895
# after removing outliers: 45918
# outliers: 2977

# %%
sns.boxplot(new_data['price'])
# Out:
# <Axes: ylabel='price'>
