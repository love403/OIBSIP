# %%
#!pip install pandas
import pandas as pd

# %%
df= pd.read_csv('C:/Users/HP/Downloads/retail_sales_dataset.csv', header = 0)

# %%
df.head(20)
# Out:
#     Transaction ID        Date  Year Customer ID  Gender  Age  \
# 0                1  11/24/2023  2023     CUST001    Male   34
# 1                2   2/27/2023  2023     CUST002  Female   26
# 2                3   1/13/2023  2023     CUST003    Male   50
# 3                4   5/21/2023  2023     CUST004    Male   37
# 4                5    5/6/2023  2023     CUST005    Male   30
# 5                6   4/25/2023  2023     CUST006  Female   45
# 6                7   3/13/2023  2023     CUST007    Male   46
# 7                8   2/22/2023  2023     CUST008    Male   30
# 8                9  12/13/2023  2023     CUST009    Male   63
# 9               10   10/7/2023  2023     CUST010  Female   52
# 10              11   2/14/2023  2023     CUST011    Male   23
# 11              12  10/30/2023  2023     CUST012    Male   35
# 12              13    8/5/2023  2023     CUST013    Male   22
# 13              14   1/17/2023  2023     CUST014    Male   64
# ...

# %% [markdown]
# ## Descriptive Analysis

# %%
df.describe()
# Out:
#        Transaction ID         Year         Age     Quantity  Price per Unit  \
# count     1000.000000  1000.000000  1000.00000  1000.000000     1000.000000
# mean       500.500000  2023.002000    41.39200     2.514000      179.890000
# std        288.819436     0.044699    13.68143     1.132734      189.681356
# min          1.000000  2023.000000    18.00000     1.000000       25.000000
# 25%        250.750000  2023.000000    29.00000     1.000000       30.000000
# 50%        500.500000  2023.000000    42.00000     3.000000       50.000000
# 75%        750.250000  2023.000000    53.00000     4.000000      300.000000
# max       1000.000000  2024.000000    64.00000     4.000000      500.000000
#
#        Total Amount
# count   1000.000000
# mean     456.000000
# std      559.997632
# min       25.000000
# 25%       60.000000
# 50%      135.000000
# 75%      900.000000
# max     2000.000000

# %%
print(df.dtypes)
# Out:
# Transaction ID       int64
# Date                object
# Year                 int64
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# ## Converting the date data type to datetime

# %%
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Year              1000 non-null   int64
#  3   Customer ID       1000 non-null   object
#  4   Gender            1000 non-null   object
#  5   Age               1000 non-null   int64
#  6   Product Category  1000 non-null   object
#  7   Quantity          1000 non-null   int64
#  8   Price per Unit    1000 non-null   int64
#  9   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 78.3+ KB

# %% [markdown]
# ## Creating a new column for Month

# %%
# month
df["Date"].dt.month
# Out:
# 0      11
# 1       2
# 2       1
# 3       5
# 4       5
#        ..
# 995     5
# 996    11
# 997    10
# 998    12
# 999     4
# Name: Date, Length: 1000, dtype: int32

# %%
df["Month"]=df["Date"].dt.month

# %%
df.sample(20)
# Out:
#      Transaction ID       Date  Year Customer ID  Gender  Age  \
# 998             999 2023-12-05  2023     CUST999  Female   36
# 759             760 2023-03-27  2023     CUST760    Male   27
# 83               84 2023-11-28  2023     CUST084  Female   38
# 141             142 2023-02-02  2023     CUST142    Male   35
# 305             306 2023-08-21  2023     CUST306    Male   54
# 483             484 2023-01-13  2023     CUST484  Female   19
# 359             360 2023-03-09  2023     CUST360    Male   42
# 242             243 2023-05-23  2023     CUST243  Female   47
# 277             278 2023-03-13  2023     CUST278  Female   37
# 589             590 2023-03-17  2023     CUST590    Male   36
# 806             807 2023-08-11  2023     CUST807  Female   50
# 797             798 2023-08-04  2023     CUST798    Male   61
# 482             483 2023-04-25  2023     CUST483    Male   55
# 476             477 2023-04-24  2023     CUST477    Male   43
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## Time Series Analysis

# %%
sns.lineplot(x = "Month", y = "Total Amount", data = df)
# Out:
# <Axes: xlabel='Month', ylabel='Total Amount'>

# %% [markdown]
# ## Product Analysis

# %%
sns.countplot(x = "Product Category",data = df, palette = 'Set3')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10940\72402266.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Product Category",data = df, palette = 'Set3')
# <Axes: xlabel='Product Category', ylabel='count'>

# %% [markdown]
# ## INSIGHTS WITH BARPLOT, LINEPLOTS AND HEATMAP

# %%
#Knowing the gender that bought products the more using bar chat
sns.countplot(x = "Gender", data = df, palette = 'Set2')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10940\1926860545.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "Gender", data = df, palette = 'Set2')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#Knowing the Age that bought products the more using bar chat
sns.lineplot(x = "Age",y = "Total Amount", data = df, color= 'Red')
# Out:
# <Axes: xlabel='Age', ylabel='Total Amount'>

# %%
df["Total Amount"]
# Out:
# 0       150
# 1      1000
# 2        30
# 3       500
# 4       100
#        ...
# 995      50
# 996      90
# 997     100
# 998     150
# 999     120
# Name: Total Amount, Length: 1000, dtype: int64

# %%
df["Product Category"]
# Out:
# 0           Beauty
# 1         Clothing
# 2      Electronics
# 3         Clothing
# 4           Beauty
#           ...
# 995       Clothing
# 996         Beauty
# 997         Beauty
# 998    Electronics
# 999    Electronics
# Name: Product Category, Length: 1000, dtype: object

# %% [markdown]
# ## HEATMAP

# %%
df.head(20)
# Out:
#     Transaction ID       Date  Year Customer ID  Gender  Age Product Category  \
# 0                1 2023-11-24  2023     CUST001    Male   34           Beauty
# 1                2 2023-02-27  2023     CUST002  Female   26         Clothing
# 2                3 2023-01-13  2023     CUST003    Male   50      Electronics
# 3                4 2023-05-21  2023     CUST004    Male   37         Clothing
# 4                5 2023-05-06  2023     CUST005    Male   30           Beauty
# 5                6 2023-04-25  2023     CUST006  Female   45           Beauty
# 6                7 2023-03-13  2023     CUST007    Male   46         Clothing
# 7                8 2023-02-22  2023     CUST008    Male   30      Electronics
# 8                9 2023-12-13  2023     CUST009    Male   63      Electronics
# 9               10 2023-10-07  2023     CUST010  Female   52         Clothing
# 10              11 2023-02-14  2023     CUST011    Male   23         Clothing
# ...

# %% [markdown]
# ## Creating a copy of my dataframe

# %%
df3 = df.copy()

# %%
df3.sample(5)
# Out:
#      Transaction ID       Date  Year Customer ID  Gender  Age  \
# 57               58 2023-11-13  2023     CUST058    Male   18
# 604             605 2023-07-24  2023     CUST605    Male   37
# 578             579 2023-09-21  2023     CUST579  Female   38
# 121             122 2023-10-03  2023     CUST122    Male   64
# 158             159 2023-05-31  2023     CUST159    Male   26
#
#     Product Category  Quantity  Price per Unit  Total Amount  Month
# 57          Clothing         4             300          1200     11
# 604      Electronics         2             500          1000      7
# 578      Electronics         1              30            30      9
# 121      Electronics         4              30           120     10
# 158         Clothing         4              50           200      5

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# ## BASICS

# %%
df3.groupby('Product Category').Quantity.value_counts()
# Out:
# Product Category  Quantity
# Beauty            3           85
#                   2           75
#                   1           74
#                   4           73
# Clothing          4           97
#                   1           88
#                   3           86
#                   2           80
# Electronics       4           93
#                   1           91
#                   2           88
#                   3           70
# Name: count, dtype: int64

# %% [markdown]
# ## UNSTACK DATA

# %%
(df3
 .groupby('Product Category')
 .Quantity
 .value_counts()
 .unstack()
)
# Out:
# Quantity           1   2   3   4
# Product Category
# Beauty            74  75  85  73
# Clothing          88  80  86  97
# Electronics       91  88  70  93

# %%
df2=(
    df3
 .groupby('Product Category')
 .Quantity
 .value_counts()
 .unstack()
)

# %%
sns.heatmap(df2);

# %% [markdown]
# ## ANNOTATIONS OF NUMBERS ON MY HEATMAP

# %%
sns.heatmap(df2, annot = True);

# %% [markdown]
# ## ACTIONABLE RECOMMENDATION

# %% [markdown]
# ### Below are my observations and recommendations
#
# * The monthly time series shows that sales dropped rapidly in March, April, August, and September, while the month of February recorded the highest sales as well as the month of May.
# * The Product Analysis shows that the Clothing sold more than the Electronics and Beauty products.
# * The products were mostly patronized by the female more than the male.
# * Products were mostly purchased by people between the age of 30-40 years.
# * The heatmap visualization explains the purchase rate, and Clothing has the highest purchased.
